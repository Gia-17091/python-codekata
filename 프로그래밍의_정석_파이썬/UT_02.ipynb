# %% [markdown]
# <a href="https://colab.research.google.com/github/Gia-17091/python-codekata/blob/main/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EC%9D%98_%EC%A0%95%EC%84%9D_%ED%8C%8C%EC%9D%B4%EC%8D%AC_UT_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 실습 2.1] 키보드 입력과 반올림
r = float(input("반지름을 입력하시오: "))
area = 3.14 * r * r
area = round(area, 1)
print(f"The area of a circle with radius {r} is {area}")
# Out:
# 반지름을 입력하시오: 3
# The area of a circle with radius 3.0 is 28.3

# %%
# 실습 2.2] 동전 합산 서비스
print("Enter the number of coins you have.")
won_500 = int(input("500원 동전 개수: "))
won_100 = int(input("100원 동전 개수: "))
won_50 = int(input("50원 동전 개수: "))
won_10 = int(input("10원 동전 개수: "))

total = won_500 * 500 + won_100 * 100 + won_50 * 50 + won_10 * 10
print(f"You have {total} won in total.")
# Out:
# Enter the number of coins you have.
# 500원 동전 개수: 4
# 100원 동전 개수: 2
# 50원 동전 개수: 3
# 10원 동전 개수: 4
# You have 2390 won in total.

# %%
# 실습 2.3] 온도 변환 서비스
# C = (F-32) * (5/9)

print("Fahrenheit to Celsius conversion")
F = float(input("Degrees in Fahrenheit?"))

c = (F-32) * (5/9)
c = round(C, 1)
print(f"{c} degrees in Celsius")
# Out:
# Fahrenheit to Celsius conversion
# Degrees in Fahrenheit?67
# 19.4 degrees in Celsius

# %%
# 실습 2.4] 동전 합산 함수
def coin_in_total(c500, c100, c50, c10):
  return c500 * 500 + c100 * 100 + c50 * 50 + c10 * 10

# Test Code
print(coin_in_total(4,2,3,4))
# Out:
# 2390

# %%
# 실습 2.5] 온도 변환 함수
# C = (F-32) * (5/9)
print("Fahrenheit to Celsius conversion")
def fahrenheit_to_celsius(F):
  c = (F-32) * (5/9)
  return c

# Test Code
print(fahrenheit_to_celsius(67))
print(round(fahrenheit_to_celsius(67),1))
# Out:
# Fahrenheit to Celsius conversion
# 19.444444444444446
# 19.4

# %%
# 실습 2.6 9의 보수 계산 함수
# 9의 보수 구하는 공식] 10^k -1 -n (자연수 n, 자리수 k)

def complement_nine(n):
  k=len(str(n))
  return 10**k -1 -n

# Test Code
print(complement_nine(0))
print(complement_nine(9))
print(complement_nine(4))
print(complement_nine(18))
print(complement_nine(40))
print(complement_nine(307))
print(complement_nine(9142))
print(complement_nine(9965))
print(complement_nine(9999))
# Out:
# 9
# 0
# 5
# 81
# 59
# 692
# 857
# 34
# 0

# %%
# 연습 문제 2.1] 온도 변환 함수

def celsius2celsius2fahrenheit(C):
  F = (C * 9/5) + 32
  return F

# Test Code
print(celsius2celsius2fahrenheit(19.4))
print(round(celsius2celsius2fahrenheit(19.4),1))
# Out:
# 66.92
# 66.9

# %%
# 연습문제 2.2] 대출 원리금 균등분활 상환금 계산
# 이자: 복리 계산(원금 p, 월 이자율 r, 상환월 m)
 # d = {(1+r)**m * p * r} / {(1+r)**m -1}
def monthly_payment_plan(p,r, m):
  m = m * 12
  r = r / 100 / 12
  d= ((1+r)**m * p * r) / ((1+r)**m -1)
  return int(d)

# Test Code
print(monthly_payment_plan(10000000, 2.8, 4))
# Out:
# 220460

# %%
# 연습문제 2.2-나] 시스템 구현
print("자유은행 대출 상환금 계산 서비스에 오심을 환영합니다.")
p = int(input("대출 원금이 얼마인가요(백만원 이상)"))
r = float(input("연 이자율은 몇 %인가요(0.0~9.9) "))
m = int(input("상한기간은 몇 년인가요? "))
d = int(((1+r)**m * p * r) / ((1+r)**m -1))

print("대출 상환금 내역을 알려드리겠습니다.")
print(f"대출 원금: {p} 원")
print(f"연 이자율 {r} 매월 총 상환금액은 {p} 원입니다.")
print(f"상환 완료시까지 총 상환금액은 {d}원입니다.")

print("저희 자유은행은 항상 여러분과 함께 합니다.")
print("또 들려주세요.")
# Out:
# 자유은행 대출 상환금 계산 서비스에 오심을 환영합니다.
# 대출 원금이 얼마인가요(백만원 이상)5000000
# 연 이자율은 몇 %인가요(0.0~9.9) 2.9
# 상한기간은 몇 년인가요? 4
# 대출 상환금 내역을 알려드리겠습니다.
# 대출 원금: 5000000 원
# 연 이자율 2.9 매월 총 상환금액은 5000000 원입니다.
# 상환 완료시까지 총 상환금액은 14562949원입니다.
# 저희 자유은행은 항상 여러분과 함께 합니다.
# 또 들려주세요.
