# %% [markdown]
# <a href="https://colab.research.google.com/github/Gia-17091/python-codekata/blob/main/UT_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 실습 3.1] 짝수 확인 함수
def even(n):
  if n % 2 == 0:
    return True
  else:
    return False

# Tast Code
print(even(13))
print(even(26))
# Out:
# False
# True

# %%
# 실습 3.2] 흐름도 그리기
score = int(input("Enter your score : "))
if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
elif score >= 60:
  print("D")
elif 0 <= score <=59:
  print("F")
else:
  print("Your score is out of range.")
# Out:
# Enter your score : 90
# A

# %%
# 실습 3.3] 중첩 선택문의 실행 경로 따져보기

x = int(input("Enter the Number: "))
if x % 2 == 0 and x % 3 == 0:
  print(x, "is divisible by 2 and 3")
elif x % 2 == 0 and not(x % 3 == 0):
  print(x, "is divisible by 2 but not by 3")
elif not(x % 2 == 0) and x % 3 == 0:
  print(x, "is divisible by 3 but not by 2")
else:
  print(x, "is not divisible by 2 and 3")
# Out:
# Enter the Number: 10
# 10 is divisible by 2 but not by 3

# %%
# 실습 3.4] 둘 중 작은 수 찾기 함수

def smaller(x,y):
  if x< y:
    return x
  else:
    return y

# Test Code
print(smaller(3, 5))
print(smaller(5, 3))
print(smaller(3, 3))
# Out:
# 3
# 3
# 3

# %%
# 실습 3.5] 셋 중 가장 작은 수 찾기 함수

def smallest(x,y,z):
  if x < y :
    if x < z:
      return x
    else:
      return z
  else:
    if y < z:
      return y
    else:
      return z

# Test Code
print(smallest(3, 5, 9))
print(smallest(5, 3, 9))
print(smallest(5, 9, 3))
print(smallest(3, 9, 5))
print(smallest(9, 3, 5))
print(smallest(9, 5, 3))
# Out:
# 3
# 3
# 3
# 3
# 3
# 3

# %%
# 실습 3.7] 수강과목 평균 점수 계산 서비스

print("Score Average Calculator")
count_sub = int(input("How many classes? "))

sub = 0
sum_sub = 0
while sub < count_sub:
  score = float(input("Enter your score: "))
  sub +=1
  sum_sub += score

avg_sub = sum_sub / count_sub
avg_sub = round(avg_sub, 1)
print("Your average score is", avg_sub)
# Out:
# Score Average Calculator
# How many classes? 5
# Enter your score: 82
# Enter your score: 96
# Enter your score: 94
# Enter your score: 82
# Enter your score: 79
# Your average score is 86.6

# %%
# 실습 3.8] 수강과목 평균 계산 서비스
print("Score Average Calculator")
count_sub = input("How many classes? ")

while not count_sub.isdigit():
 count_sub = int(input("Enter a positive number: "))
count_sub = int(count_sub)

sub = 0
sum_sub = 0
while sub < count_sub:
  score = float(input("Enter your score: "))
  while not (0 <= score <= 100):
    score = int(input("Enter your score between 0 and 100: "))
    break
  sub +=1
  sum_sub += score

avg_sub = sum_sub / count_sub
avg_sub = round(avg_sub, 1)
print("Your average score is", avg_sub)
# Out:
# Score Average Calculator
# How many classes? 5
# Enter your score: 200
# Enter your score between 0 and 100: 100
# Enter your score: 90
# Enter your score: 80
# Enter your score: 20
# Enter your score: 30
# Your average score is 64.0

# %%
# 실습 3.9] 정수 문자열 확인 함수(음수 포함)
def isinteger(n):
  return n.isdigit() or n!='' and n[0]=='-' and n[1:].isdigit()

# Test code
print(isinteger("55"))
print(isinteger("66o6"))
# Out:
# True
# False

# %%
# 실습 3.10] 실수 문자열 확인 함수(음수 포함)
def isinteger(n):
  return n.isdigit() or n!='' and n[0]=='-' and n[1:].isdigit()

def isfloat(s):
    (num, dot, fraction) = s.partition('.')
    return dot == '' and fraction == '' and isinteger(num) or \
           dot == '.' and \
           ((num == '' or num == '-') and fraction.isdigit() or \
            fraction == '' and isinteger(num) or \
            isinteger(num) and fraction.isdigit())

# Test code
print(isinteger("55"))
print(isinteger("66o6"))
# Out:
# True
# False
